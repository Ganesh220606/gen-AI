# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganesh220606/gen-AI/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio

# %%
import gradio as gr

def smart_home_agent(temperature):
    if temperature > 26:
        return f"🌡️ Room Temperature: {temperature} °C\n\n❄️ Action: Air Conditioner ON"
    elif temperature < 22:
        return f"🌡️ Room Temperature: {temperature} °C\n\n🔴 Action: Air Conditioner OFF"
    else:
        return f"🌡️ Room Temperature: {temperature} °C\n\n✅ Comfortable Temperature - No Change"

interface = gr.Interface(
    fn=smart_home_agent,
    inputs=gr.Slider(10, 40, value=25, label="Room Temperature (°C)"),
    outputs=gr.Textbox(label="Agent Decision"),
    title="🏠 Smart Home Temperature Control Agent",
    description="Enter the room temperature and let the intelligent agent decide whether to switch the AC ON or OFF."
)

interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://60199d671bbe4752f6.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://60199d671bbe4752f6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
